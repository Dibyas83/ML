# %% [markdown]
# <a href="https://colab.research.google.com/github/Dibyas83/ML/blob/main/campusx1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv('/content/placementbig.csv')

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
df2 =pd.read_csv('/content/placement.csv')

# %%
df2.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
# !kaggle kernels pull georgyzubkov/college-data-exploratory-data-analysis
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 4, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/__init__.py", line 6, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 434, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

# %%
# !kaggle kernels pull georgyzubkov/college-data-exploratory-data-analysis
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 4, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/__init__.py", line 6, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 434, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.config/kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle kernels pull georgyzubkov/college-data-exploratory-data-analysis
# Out:
# ...
# Source code downloaded to /content/college-data-exploratory-data-analysis.ipynb

# %%
df3 = pd.read_csv('/content/college-data-exploratory-data-analysis.ipynb')

# %%
df3.head()
# Out:
# Empty DataFrame
# ...

# %%
df4 = pd.read_csv('/content/placement-dataset.csv')

# %%
df4.head()
# Out:
#           city  cgpa     iq  placement
# 0     New York   6.8  123.0          1
# 1  Los Angeles   5.9  106.0          0
# 2      Chicago   NaN  121.0          0
# 3     New York   7.4  132.0          1
# 4  Los Angeles   5.8  142.0          0

# %%
df4.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3559295218.py in <cell line: 0>()
# ----> 1 df4.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df4.shape
# Out:
# (100, 4)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       100 non-null    object
#  1   cgpa       92 non-null     float64
#  2   iq         96 non-null     float64
#  3   placement  100 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.3+ KB

# %%
df4 = df4.dropna()

# %%
df4 = df4.iloc[ :,1: ]

# %%
df4.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0
# 5   7.1   48.0          1

# %%
df4.dropna()
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# 5    7.1   48.0          1
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [88 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df4['cgpa'],df4['iq'],c = df4['placement'])

# %%
x = df4.iloc[:,0:2]
y = df4.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 3    7.4  132.0
# 4    5.8  142.0
# 5    7.1   48.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [88 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 38   6.5  160.0
# 42   7.6   89.0
# 58   8.0   79.0
# 55   7.8  114.0
# 77   7.3   50.0
# ..   ...    ...
# 22   4.9  120.0
# 27   6.0  124.0
# 94   4.7   52.0
# 3    7.4  132.0
# 85   5.8  166.0
#
# [79 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.40816252,  0.93972765],
#        [ 1.37992478, -0.79928006],
#        [ 1.73329287, -1.04421073],
#        [ 1.55660883, -0.1869534 ],
#        [ 1.11489871, -1.75450965],
#        [ 0.31982049, -0.13796727],
#        [ 1.29158275, -1.48508592],
#        [ 0.23147847, -0.45637713],
#        [ 0.23147847,  0.13145646],
#        [ 0.76153061, -0.6278286 ],
#        [-2.2420982 ,  2.72772149],
#        [-0.82862582,  0.15594952],
#        [-0.82862582, -1.36262059],
#        [ 0.31982049,  0.47435939],
#        [-1.44701999, -1.95045418],
#        [-1.44701999,  0.67030392],
#        [-0.0335476 , -1.87697498],
#        [-0.7402838 ,  0.25392179],
#        [-1.09365189,  1.16016524],
#        [-1.09365189, -0.23593954],
#        [-0.0335476 , -0.4808702 ],
#        [ 1.99831895,  1.13567218],
#        [-0.56359975,  0.32740099],
#        [ 1.11489871,  0.37638712],
#        [ 0.93821466, -1.80349578],
#        [-0.65194177, -0.1869534 ],
#        [ 1.11489871, -0.87275926],
# ...

# %%
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model  import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
clf.predict(x_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# array([1, 0, 0, 0, 0, 0, 1, 0, 1])

# %%
y_test
# Out:
# 99    1
# 21    1
# 17    0
# 24    0
# 80    0
# 84    0
# 25    0
# 65    1
# 56    0
# Name: placement, dtype: int64

# %%
y_pred = clf.predict(x_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5555555555555556

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
